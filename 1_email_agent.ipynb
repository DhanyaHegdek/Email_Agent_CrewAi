# %%
# %pip install python-dotenv
from dotenv import load_dotenv
load_dotenv()
# Out:
# Requirement already satisfied: python-dotenv in .\.venv\Lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# True

# %%
# %pip install crewai crewai-tools
# Out:
# Requirement already satisfied: crewai in .\.venv\Lib\site-packages (1.15.5)
# Requirement already satisfied: crewai-tools in .\.venv\Lib\site-packages (1.15.5)
# Requirement already satisfied: aiofiles~=24.1.0 in .\.venv\Lib\site-packages (from crewai) (24.1.0)
# Requirement already satisfied: aiosqlite~=0.21.0 in .\.venv\Lib\site-packages (from crewai) (0.21.0)
# Requirement already satisfied: appdirs~=1.4.4 in .\.venv\Lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: cel-python<0.6,>=0.5.0 in .\.venv\Lib\site-packages (from crewai) (0.5.0)
# Requirement already satisfied: chromadb~=1.1.0 in .\.venv\Lib\site-packages (from crewai) (1.1.1)
# Requirement already satisfied: click<9,>=8.1.7 in .\.venv\Lib\site-packages (from crewai) (8.4.2)
# Requirement already satisfied: crewai-cli==1.15.5 in .\.venv\Lib\site-packages (from crewai) (1.15.5)
# Requirement already satisfied: crewai-core==1.15.5 in .\.venv\Lib\site-packages (from crewai) (1.15.5)
# Requirement already satisfied: httpx~=0.28.1 in .\.venv\Lib\site-packages (from crewai) (0.28.1)
# Requirement already satisfied: instructor>=1.3.3 in .\.venv\Lib\site-packages (from crewai) (1.15.4)
# Requirement already satisfied: json-repair~=0.25.2 in .\.venv\Lib\site-packages (from crewai) (0.25.3)
# Requirement already satisfied: json5~=0.10.0 in .\.venv\Lib\site-packages (from crewai) (0.10.0)
# Requirement already satisfied: jsonref~=1.1.0 in .\.venv\Lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: lancedb<0.30.1,>=0.29.2 in .\.venv\Lib\site-packages (from crewai) (0.30.0)
# Requirement already satisfied: mcp~=1.28.1 in .\.venv\Lib\site-packages (from crewai) (1.28.1)
# Requirement already satisfied: openai<3,>=2.30.0 in .\.venv\Lib\site-packages (from crewai) (2.46.0)
# Requirement already satisfied: openpyxl~=3.1.5 in .\.venv\Lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api~=1.42.0 in .\.venv\Lib\site-packages (from crewai) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http~=1.42.0 in .\.venv\Lib\site-packages (from crewai) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk~=1.42.0 in .\.venv\Lib\site-packages (from crewai) (1.42.1)
# Requirement already satisfied: pdfplumber~=0.11.4 in .\.venv\Lib\site-packages (from crewai) (0.11.10)
# Requirement already satisfied: portalocker~=2.7.0 in .\.venv\Lib\site-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic-settings<3,>=2.10.1 in .\.venv\Lib\site-packages (from crewai) (2.10.1)
# Requirement already satisfied: pydantic<2.13,>=2.11.9 in .\.venv\Lib\site-packages (from crewai) (2.12.5)
# Requirement already satisfied: pyjwt<3,>=2.13.0 in .\.venv\Lib\site-packages (from crewai) (2.13.0)
# Requirement already satisfied: python-dotenv<2,>=1.2.2 in .\.venv\Lib\site-packages (from crewai) (1.2.2)
# Requirement already satisfied: pyyaml~=6.0 in .\.venv\Lib\site-packages (from crewai) (6.0.3)
# Requirement already satisfied: regex~=2026.1.15 in .\.venv\Lib\site-packages (from crewai) (2026.1.15)
# Requirement already satisfied: tokenizers<1,>=0.21 in .\.venv\Lib\site-packages (from crewai) (0.23.1)
# Requirement already satisfied: tomli-w~=1.1.0 in .\.venv\Lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: tomli~=2.0.2 in .\.venv\Lib\site-packages (from crewai) (2.0.2)
# Requirement already satisfied: certifi in .\.venv\Lib\site-packages (from crewai-cli==1.15.5->crewai) (2026.7.22)
# Requirement already satisfied: cryptography>=42.0 in .\.venv\Lib\site-packages (from crewai-cli==1.15.5->crewai) (49.0.0)
# Requirement already satisfied: packaging>=23.0 in .\.venv\Lib\site-packages (from crewai-cli==1.15.5->crewai) (26.2)
# Requirement already satisfied: rich>=13.7.1 in .\.venv\Lib\site-packages (from crewai-cli==1.15.5->crewai) (14.3.4)
# Requirement already satisfied: textual>=7.5.0 in .\.venv\Lib\site-packages (from crewai-cli==1.15.5->crewai) (8.2.8)
# Requirement already satisfied: uv~=0.11.6 in .\.venv\Lib\site-packages (from crewai-cli==1.15.5->crewai) (0.11.31)
# Requirement already satisfied: typing_extensions>=4.0 in .\.venv\Lib\site-packages (from aiosqlite~=0.21.0->crewai) (4.16.0)
# Requirement already satisfied: google-re2>=1.1.20240702 in .\.venv\Lib\site-packages (from cel-python<0.6,>=0.5.0->crewai) (1.1.20251105)
# Requirement already satisfied: jmespath>=1.0.1 in .\.venv\Lib\site-packages (from cel-python<0.6,>=0.5.0->crewai) (1.1.0)
# Requirement already satisfied: lark>=1.2.2 in .\.venv\Lib\site-packages (from cel-python<0.6,>=0.5.0->crewai) (1.3.1)
# Requirement already satisfied: pendulum>=3.1.0 in .\.venv\Lib\site-packages (from cel-python<0.6,>=0.5.0->crewai) (3.2.0)
# Requirement already satisfied: build>=1.0.3 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (1.5.0)
# Requirement already satisfied: pybase64>=1.4.1 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in .\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.51.0)
# Requirement already satisfied: numpy>=1.22.5 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (2.5.1)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (1.42.1)
# Requirement already satisfied: pypika>=0.48.9 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (4.69.0)
# Requirement already satisfied: overrides>=7.3.1 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (1.82.1)
# Requirement already satisfied: bcrypt>=4.0.1 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (0.27.0)
# Requirement already satisfied: kubernetes>=28.1.0 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (36.0.3)
# Requirement already satisfied: tenacity>=8.2.3 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (9.1.4)
# Requirement already satisfied: mmh3>=4.0.1 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (3.11.9)
# Requirement already satisfied: jsonschema>=4.19.0 in .\.venv\Lib\site-packages (from chromadb~=1.1.0->crewai) (4.26.0)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click<9,>=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: anyio in .\.venv\Lib\site-packages (from httpx~=0.28.1->crewai) (4.14.2)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx~=0.28.1->crewai) (1.0.9)
# Requirement already satisfied: idna in .\.venv\Lib\site-packages (from httpx~=0.28.1->crewai) (3.18)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx~=0.28.1->crewai) (0.16.0)
# Requirement already satisfied: deprecation>=2.1.0 in .\.venv\Lib\site-packages (from lancedb<0.30.1,>=0.29.2->crewai) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in .\.venv\Lib\site-packages (from lancedb<0.30.1,>=0.29.2->crewai) (25.0.0)
# Requirement already satisfied: lance-namespace>=0.3.2 in .\.venv\Lib\site-packages (from lancedb<0.30.1,>=0.29.2->crewai) (0.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in .\.venv\Lib\site-packages (from mcp~=1.28.1->crewai) (0.4.3)
# Requirement already satisfied: python-multipart>=0.0.9 in .\.venv\Lib\site-packages (from mcp~=1.28.1->crewai) (0.0.32)
# Requirement already satisfied: pywin32>=310 in .\.venv\Lib\site-packages (from mcp~=1.28.1->crewai) (312)
# Requirement already satisfied: sse-starlette>=1.6.1 in .\.venv\Lib\site-packages (from mcp~=1.28.1->crewai) (3.4.6)
# Requirement already satisfied: starlette>=0.27 in .\.venv\Lib\site-packages (from mcp~=1.28.1->crewai) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in .\.venv\Lib\site-packages (from mcp~=1.28.1->crewai) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in .\.venv\Lib\site-packages (from openai<3,>=2.30.0->crewai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in .\.venv\Lib\site-packages (from openai<3,>=2.30.0->crewai) (0.14.0)
# Requirement already satisfied: sniffio in .\.venv\Lib\site-packages (from openai<3,>=2.30.0->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in .\.venv\Lib\site-packages (from openpyxl~=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in .\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in .\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in .\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (1.42.1)
# Requirement already satisfied: requests~=2.7 in .\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (2.34.2)
# Requirement already satisfied: protobuf<7.0,>=5.0 in .\.venv\Lib\site-packages (from opentelemetry-proto==1.42.1->opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (6.33.6)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in .\.venv\Lib\site-packages (from opentelemetry-sdk~=1.42.0->crewai) (0.63b1)
# Requirement already satisfied: pdfminer.six==20260107 in .\.venv\Lib\site-packages (from pdfplumber~=0.11.4->crewai) (20260107)
# Requirement already satisfied: Pillow>=12.2.0 in .\.venv\Lib\site-packages (from pdfplumber~=0.11.4->crewai) (12.3.0)
# Requirement already satisfied: pypdfium2>=5.9.0 in .\.venv\Lib\site-packages (from pdfplumber~=0.11.4->crewai) (5.12.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in .\.venv\Lib\site-packages (from pdfminer.six==20260107->pdfplumber~=0.11.4->crewai) (3.4.9)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in .\.venv\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in .\.venv\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic<2.13,>=2.11.9->crewai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\.venv\Lib\site-packages (from pydantic<2.13,>=2.11.9->crewai) (2.41.5)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (2.7.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in .\.venv\Lib\site-packages (from tokenizers<1,>=0.21->crewai) (1.24.0)
# Requirement already satisfied: filelock>=3.10.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (3.32.0)
# Requirement already satisfied: fsspec>=2023.5.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (1.5.2)
# Requirement already satisfied: beautifulsoup4~=4.13.4 in .\.venv\Lib\site-packages (from crewai-tools) (4.13.5)
# Requirement already satisfied: pymupdf~=1.26.6 in .\.venv\Lib\site-packages (from crewai-tools) (1.26.7)
# Requirement already satisfied: python-docx~=1.2.0 in .\.venv\Lib\site-packages (from crewai-tools) (1.2.0)
# Requirement already satisfied: pytube~=15.0.0 in .\.venv\Lib\site-packages (from crewai-tools) (15.0.0)
# Requirement already satisfied: tiktoken<0.13,>=0.8.0 in .\.venv\Lib\site-packages (from crewai-tools) (0.12.0)
# Requirement already satisfied: youtube-transcript-api~=1.2.2 in .\.venv\Lib\site-packages (from crewai-tools) (1.2.4)
# Requirement already satisfied: soupsieve>1.2 in .\.venv\Lib\site-packages (from beautifulsoup4~=4.13.4->crewai-tools) (2.9.1)
# Requirement already satisfied: lxml>=3.1.0 in .\.venv\Lib\site-packages (from python-docx~=1.2.0->crewai-tools) (6.1.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in .\.venv\Lib\site-packages (from youtube-transcript-api~=1.2.2->crewai-tools) (0.7.1)
# Requirement already satisfied: pyproject_hooks in .\.venv\Lib\site-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\Lib\site-packages (from cryptography>=42.0->crewai-cli==1.15.5->crewai) (2.1.0)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=42.0->crewai-cli==1.15.5->crewai) (3.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in .\.venv\Lib\site-packages (from instructor>=1.3.3->crewai) (3.14.2)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in .\.venv\Lib\site-packages (from instructor>=1.3.3->crewai) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in .\.venv\Lib\site-packages (from instructor>=1.3.3->crewai) (3.1.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.24.5)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich>=13.7.1->crewai-cli==1.15.5->crewai) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich>=13.7.1->crewai-cli==1.15.5->crewai) (2.20.0)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\Lib\site-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\Lib\site-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (0.0.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2026.6.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in .\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.9.0)
# Requirement already satisfied: requests-oauthlib in .\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in .\.venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.10)
# Requirement already satisfied: lance-namespace-urllib3-client==0.9.0 in .\.venv\Lib\site-packages (from lance-namespace>=0.3.2->lancedb<0.30.1,>=0.29.2->crewai) (0.9.0)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->crewai-cli==1.15.5->crewai) (0.1.2)
# Requirement already satisfied: flatbuffers in .\.venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (25.12.19)
# Requirement already satisfied: tzdata>=2020.1 in .\.venv\Lib\site-packages (from pendulum>=3.1.0->cel-python<0.6,>=0.5.0->crewai) (2026.3)
# Requirement already satisfied: mdit-py-plugins in .\.venv\Lib\site-packages (from textual>=7.5.0->crewai-cli==1.15.5->crewai) (0.6.1)
# Requirement already satisfied: platformdirs<5,>=3.6.0 in .\.venv\Lib\site-packages (from textual>=7.5.0->crewai-cli==1.15.5->crewai) (4.11.0)
# Requirement already satisfied: linkify-it-py<3,>=1 in .\.venv\Lib\site-packages (from markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai-cli==1.15.5->crewai) (2.1.0)
# Requirement already satisfied: uc-micro-py in .\.venv\Lib\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai-cli==1.15.5->crewai) (2.0.0)
# Requirement already satisfied: httptools>=0.8.0 in .\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in .\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: websockets>=13.0 in .\.venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (16.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in .\.venv\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from crewai import LLM

llm = LLM(
    model="gemini/gemini-3.5-flash",
    temperature=0.1
)
# Out:
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3.5-flash
# Please retry in 29.657749489s.
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit:     │
# │  20, model: gemini-3.5-flash                                                                                    │
# │  Please retry in 29.657749489s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[11], line 11
#       9     temperature=0.1
#      10 )
# ---> 11 llm.call("who invented 0")
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:335, in GeminiCompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     326         return self._handle_streaming_completion(
#     327             formatted_content,
#     328             config,
#    (...)    332             effective_response_model,
#     333         )
# --> 335     return self._handle_completion(
#     336         formatted_content,
#     337         config,
#     338         available_functions,
#     339         from_task,
#     340         from_agent,
#     341         effective_response_model,
#     342     )
#     344 except APIError as e:
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:1172, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1171         raise LLMContextLengthExceededError(str(e)) from e
# -> 1172     raise e from e
#    1174 self._track_token_usage_internal(usage)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:1161, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1160 contents_for_api: Any = contents
# -> 1161 response = self._get_sync_client().models.generate_content(
#    1162     model=self.model,
#    1163     contents=contents_for_api,
#    1164     config=config,
#    1165 )
#    1167 usage = self._extract_token_usage(response)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\models.py:5644, in Models.generate_content(self, model, contents, config)
#    5643 i += 1
# -> 5644 response = self._generate_content(
#    5645     model=model, contents=contents, config=parsed_config
#    5646 )
#    5648 function_map = _extra_utils.get_function_map(parsed_config)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\models.py:4306, in Models._generate_content(self, model, contents, config)
#    4304 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4306 response = self._api_client.request(
#    4307     'post', path, request_dict, http_options
#    4308 )
#    4310 if config is not None and getattr(
#    4311     config, 'should_return_http_response', None
#    4312 ):
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1398 http_request = self._build_request(
#    1399     http_method, path, request_dict, http_options
#    1400 )
# -> 1401 response = self._request(http_request, http_options, stream=False)
#    1402 response_body = (
#    1403     response.response_stream[0] if response.response_stream else ''
#    1404 )
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\_api_client.py:1237, in BaseApiClient._request(self, http_request, http_options, stream)
#    1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1237 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\_api_client.py:1214, in BaseApiClient._request_once(self, http_request, stream)
#    1207 response = self._httpx_client.request(
#    1208     method=http_request.method,
#    1209     url=http_request.url,
#    (...)   1212     timeout=http_request.timeout,
#    1213 )
# -> 1214 errors.APIError.raise_for_response(response)
#    1215 return HttpResponse(
#    1216     response.headers, response if stream else [response.text]
#    1217 )
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\errors.py:134, in APIError.raise_for_response(cls, response)
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3.5-flash\nPlease retry in 29.657749489s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '29s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ClientError                               Traceback (most recent call last)
# Cell In[11], line 11
#       9     temperature=0.1
#      10 )
# ---> 11 llm.call("who invented 0")
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:335, in GeminiCompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     326         return self._handle_streaming_completion(
#     327             formatted_content,
#     328             config,
#    (...)    332             effective_response_model,
#     333         )
# --> 335     return self._handle_completion(
#     336         formatted_content,
#     337         config,
#     338         available_functions,
#     339         from_task,
#     340         from_agent,
#     341         effective_response_model,
#     342     )
#     344 except APIError as e:
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:1172, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1171         raise LLMContextLengthExceededError(str(e)) from e
# -> 1172     raise e from e
#    1174 self._track_token_usage_internal(usage)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:1161, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1160 contents_for_api: Any = contents
# -> 1161 response = self._get_sync_client().models.generate_content(
#    1162     model=self.model,
#    1163     contents=contents_for_api,
#    1164     config=config,
#    1165 )
#    1167 usage = self._extract_token_usage(response)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\models.py:5644, in Models.generate_content(self, model, contents, config)
#    5643 i += 1
# -> 5644 response = self._generate_content(
#    5645     model=model, contents=contents, config=parsed_config
#    5646 )
#    5648 function_map = _extra_utils.get_function_map(parsed_config)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\models.py:4306, in Models._generate_content(self, model, contents, config)
#    4304 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4306 response = self._api_client.request(
#    4307     'post', path, request_dict, http_options
#    4308 )
#    4310 if config is not None and getattr(
#    4311     config, 'should_return_http_response', None
#    4312 ):
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1398 http_request = self._build_request(
#    1399     http_method, path, request_dict, http_options
#    1400 )
# -> 1401 response = self._request(http_request, http_options, stream=False)
#    1402 response_body = (
#    1403     response.response_stream[0] if response.response_stream else ''
#    1404 )
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\_api_client.py:1237, in BaseApiClient._request(self, http_request, http_options, stream)
#    1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1237 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\_api_client.py:1214, in BaseApiClient._request_once(self, http_request, stream)
#    1207 response = self._httpx_client.request(
#    1208     method=http_request.method,
#    1209     url=http_request.url,
#    (...)   1212     timeout=http_request.timeout,
#    1213 )
# -> 1214 errors.APIError.raise_for_response(response)
#    1215 return HttpResponse(
#    1216     response.headers, response if stream else [response.text]
#    1217 )
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\errors.py:134, in APIError.raise_for_response(cls, response)
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3.5-flash\nPlease retry in 29.657749489s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '29s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ClientError                               Traceback (most recent call last)
# Cell In[11], line 11
#       7 llm = LLM(
#       8     model="gemini/gemini-3.5-flash",
#       9     temperature=0.1
#      10 )
# ---> 11 llm.call("who invented 0")
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:335, in GeminiCompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     325     if self._effective_stream():
#     326         return self._handle_streaming_completion(
#     327             formatted_content,
#     328             config,
#    (...)    332             effective_response_model,
#     333         )
# --> 335     return self._handle_completion(
#     336         formatted_content,
#     337         config,
#     338         available_functions,
#     339         from_task,
#     340         from_agent,
#     341         effective_response_model,
#     342     )
#     344 except APIError as e:
#     345     error_msg = f"Google Gemini API error: {e.code} - {e.message}"
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:1172, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1170         logging.error(f"Context window exceeded: {e}")
#    1171         raise LLMContextLengthExceededError(str(e)) from e
# -> 1172     raise e from e
#    1174 self._track_token_usage_internal(usage)
#    1176 return self._process_response_with_tools(
#    1177     response=response,
#    1178     contents=contents,
#    (...)   1183     usage=usage,
#    1184 )
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\crewai\llms\providers\gemini\completion.py:1161, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1158 try:
#    1159     # The API accepts list[Content] but mypy is overly strict about variance
#    1160     contents_for_api: Any = contents
# -> 1161     response = self._get_sync_client().models.generate_content(
#    1162         model=self.model,
#    1163         contents=contents_for_api,
#    1164         config=config,
#    1165     )
#    1167     usage = self._extract_token_usage(response)
#    1168 except Exception as e:
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\models.py:5644, in Models.generate_content(self, model, contents, config)
#    5642 while remaining_remote_calls_afc > 0:
#    5643   i += 1
# -> 5644   response = self._generate_content(
#    5645       model=model, contents=contents, config=parsed_config
#    5646   )
#    5648   function_map = _extra_utils.get_function_map(parsed_config)
#    5649   if not function_map:
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\models.py:4306, in Models._generate_content(self, model, contents, config)
#    4303 request_dict = _common.convert_to_dict(request_dict)
#    4304 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4306 response = self._api_client.request(
#    4307     'post', path, request_dict, http_options
#    4308 )
#    4310 if config is not None and getattr(
#    4311     config, 'should_return_http_response', None
#    4312 ):
#    4313   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1391 def request(
#    1392     self,
#    1393     http_method: str,
#    (...)   1396     http_options: Optional[HttpOptionsOrDict] = None,
#    1397 ) -> SdkHttpResponse:
#    1398   http_request = self._build_request(
#    1399       http_method, path, request_dict, http_options
#    1400   )
# -> 1401   response = self._request(http_request, http_options, stream=False)
#    1402   response_body = (
#    1403       response.response_stream[0] if response.response_stream else ''
#    1404   )
#    1405   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\_api_client.py:1237, in BaseApiClient._request(self, http_request, http_options, stream)
#    1234     retry = tenacity.Retrying(**retry_kwargs)
#    1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1237 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\_api_client.py:1214, in BaseApiClient._request_once(self, http_request, stream)
#    1206 else:
#    1207   response = self._httpx_client.request(
#    1208       method=http_request.method,
#    1209       url=http_request.url,
#    (...)   1212       timeout=http_request.timeout,
#    1213   )
# -> 1214   errors.APIError.raise_for_response(response)
#    1215   return HttpResponse(
#    1216       response.headers, response if stream else [response.text]
#    1217   )
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\errors.py:134, in APIError.raise_for_response(cls, response)
#     131 else:
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\Admin1\Desktop\Crew\crew_ai_demo\.venv\Lib\site-packages\google\genai\errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     145 """Raises an appropriate APIError subclass based on the status code.
#     146
#     147 Args:
#    (...)    156   APIError: For other error status codes.
#     157 """
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#     161   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3.5-flash\nPlease retry in 29.657749489s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '29s'}]}}

# %%
from crewai import Agent, Task , Crew
email_assistant = Agent(
    role = "email assistant agent",
    goal="improve emails and make them sound professional and clear ",
    backstory="A highly experienced communication expert skilled in professional email writing",
    verbose=True,
    llm=llm
)

original_email = """
hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.
Maybe we can show what we have and say rest is WIP.
Let me know what u think. thanks
"""

email_task = Task(
    description=f"""Take the following rough email and rewrite it into a professional and polished version.
    Expand abbreviations:
    '''{original_email}'''""",
    agent=email_assistant,
    expected_output="A professional written email with proper formatting and content.",
)

crew = Crew(
    agents = [email_assistant],
    tasks = [email_task],
    verbose=True
)

# result = crew.kickoff()
# print(result)

result = await crew.kickoff_async()
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 98a3986a-2af0-47fe-a56b-5ffc8e741005                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Take the following rough email and rewrite it into a professional and polished version.                  │
# │      Expand abbreviations:                                                                                      │
# │      '''                                                                                                        │
# │  hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.                  │
# │  Maybe we can show what we have and say rest is WIP.                                                            │
# │  Let me know what u think. thanks                                                                               │
# │  '''                                                                                                            │
# │  ID: af203b6e-dec8-4399-b426-70f5db7241fe                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: email assistant agent                                                                                   │
# │                                                                                                                 │
# │  Task: Take the following rough email and rewrite it into a professional and polished version.                  │
# │      Expand abbreviations:                                                                                      │
# │      '''                                                                                                        │
# │  hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.                  │
# │  Maybe we can show what we have and say rest is WIP.                                                            │
# │  Let me know what u think. thanks                                                                               │
# │  '''                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: email assistant agent                                                                                   │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Subject: Update on Demo Status and Proposed Next Steps                                                         │
# │                                                                                                                 │
# │  Hi Team,                                                                                                       │
# │                                                                                                                 │
# │  I wanted to provide a quick update on the status of the demo. While the core components are ready, there are   │
# │  still a few outstanding items that need to be completed.                                                       │
# │                                                                                                                 │
# │  I propose that we present the completed features during our upcoming session and clarify that the remaining    │
# │  elements are currently a work in progress.                                                                     │
# │                                                                                                                 │
# │  Please let me know your thoughts on this approach.                                                             │
# │                                                                                                                 │
# │  Thank you,                                                                                                     │
# │                                                                                                                 │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Take the following rough email and rewrite it into a professional and polished version.                  │
# │      Expand abbreviations:                                                                                      │
# │      '''                                                                                                        │
# │  hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.                  │
# │  Maybe we can show what we have and say rest is WIP.                                                            │
# │  Let me know what u think. thanks                                                                               │
# │  '''                                                                                                            │
# │  Agent: email assistant agent                                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 98a3986a-2af0-47fe-a56b-5ffc8e741005                                                                       │
# │  Final Output: Subject: Update on Demo Status and Proposed Next Steps                                           │
# │                                                                                                                 │
# │  Hi Team,                                                                                                       │
# │                                                                                                                 │
# │  I wanted to provide a quick update on the status of the demo. While the core components are ready, there are   │
# │  still a few outstanding items that need to be completed.                                                       │
# │                                                                                                                 │
# │  I propose that we present the completed features during our upcoming session and clarify that the remaining    │
# │  elements are currently a work in progress.                                                                     │
# │                                                                                                                 │
# │  Please let me know your thoughts on this approach.                                                             │
# │                                                                                                                 │
# │  Thank you,                                                                                                     │
# │                                                                                                                 │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Subject: Update on Demo Status and Proposed Next Steps
#
# Hi Team,
#
# I wanted to provide a quick update on the status of the demo. While the core components are ready, there are still a few outstanding items that need to be completed.
#
# I propose that we present the completed features during our upcoming session and clarify that the remaining elements are currently a work in progress.
#
# Please let me know your thoughts on this approach.
#
# Thank you,
#
# [Your Name]
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
